# %%
import string
import re

import spacy
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.layers import Input, Embedding, Dropout, Dense
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, GlobalMaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

import tensorflow as tf
import io
from bs4 import BeautifulSoup

# %% [markdown]
# Proprocessing Pipeline

# %%
# English spacy model
nlp = spacy.load("en_core_web_sm")
# Stop word list from NLTK
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
stopword_list.append('@user')
stopword_list.append('url')
# Punctuation list from string
puncts = string.punctuation

# %%
# Kontraktionen exandieren -> Negation
def decontract_phrase(phrase):
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"shan\'t", "shall not", phrase)
    # general
    phrase = re.sub(r"n\'t", " not ", phrase)
    phrase = re.sub(r"\'re ", " are ", phrase)
    phrase = re.sub(r"\'s ", " is ", phrase)
    phrase = re.sub(r"\'d ", " would ", phrase)
    phrase = re.sub(r"\'ll ", " will ", phrase)
    phrase = re.sub(r"\'t ", " not ", phrase)
    phrase = re.sub(r"\'ve ", " have ", phrase)
    phrase = re.sub(r"\'m ", " am ", phrase)
    
    phrase = re.sub(r'\s+', ' ', phrase)

    return phrase

# %%
def get_lemma(review):
    doc = nlp(review)
    lemma_text = ' '.join([token.lemma_ for token in doc])
    
    return lemma_text

# %%
def preprocess_pipeline(review):
    # Kontraktionen expandieren
    review = decontract_phrase(review)
    # Tokenisierung und Lemmatisierung
    review = get_lemma(review)    
    # Stopwords
    review = ' '.join([token for token in review.split() if token.lower() not in stopword_list])
    # Satzzeichen
    review = ''.join([character for character in review if character not in puncts])
    # Remove multiple whitespaces
    review = re.sub(r'^\s+', '', review)
    review = re.sub(r' +', ' ', review)
    review = re.sub(r'\s+$', '', review)
    
    return review

test = ".@USER @USER and @USER MP @USER praises the 'innovative #publicsector thinking' of @USER this week in @USER  If Britain is to prosper in the 21st century, it is through embracing the #digital economy URL URL"
preprocess_pipeline(test)
# Out:
# 'USER MP praise innovative publicsector think week Britain prosper 21st century embrace digital economy'

# %%
# Normalisation
def preprocess_pipe(text):
    # HTML
    new_string = BeautifulSoup(text, "lxml").text
    # contractions
    new_string = decontract_phrase(new_string)
    # Tokenisierung und Lemmatisierung
    new_string = get_lemma(new_string) 
    # Stop Words
    new_string = ' '.join(token for token in new_string.split() if token.lower() not in stopword_list)
    # remove everything not character, digit or whitespace
    new_string = re.sub(r'[^a-zA-Z0-9\s]', '', new_string)
    # remove multiple whitespaces
    new_string = re.sub(r' +', ' ', new_string)
    # 'tokenize' by whitespace
    new_string = new_string.split()
    
    return ' '.join(new_string)

test =  ".@USER @USER and @USER MP @USER praises the 'innovative #publicsector thinking' of @USER this week in @USER  If Britain is to prosper in the 21st century, it is through embracing the #digital economy URL URL"
preprocess_pipe(test)
# Out:
# 'USER MP praise innovative publicsector think week Britain prosper 21st century embrace digital economy'

# %%
dataset_train = pd.read_csv('./Daten/Praktikum_OLID_train.csv')
dataset_dev = pd.read_csv('./Daten/Praktikum_OLID_dev.csv')
dataset_test = pd.read_csv('./Daten/Praktikum_OLID_test.csv')
dataset_train.head()
# Out:
#                                                 Text Task
# 0  @USER bakkt is doing what an ETF would have do...  OFF
# 1                  @USER I can't 😭😭 he is already 26  NOT
# 2                     @USER he is a psychic ain’t he  NOT
# 3  .@USER @USER and @USER MP @USER praises the 'i...  NOT
# 4  @USER @USER [Eric opens the door and runs to t...  OFF

# %%
# Are all columns defined?
# Non-Null Count shows how many rows for each column are well-defined
dataset_train.info()
dataset_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10481 entries, 0 to 10480
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    10481 non-null  object
#  1   Task    10481 non-null  object
# dtypes: object(2)
# memory usage: 163.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    2620 non-null   object
#  1   Task    2620 non-null   object
# dtypes: object(2)
# memory usage: 41.1+ KB

# %%
dataset_train['Preprocessed'] = dataset_train['Text'].apply(preprocess_pipeline)
dataset_dev['Preprocessed'] = dataset_dev['Text'].apply(preprocess_pipeline)
dataset_test['Preprocessed'] = dataset_test['Text'].apply(preprocess_pipeline)
dataset_train.info()
dataset_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10481 entries, 0 to 10480
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Text          10481 non-null  object
#  1   Task          10481 non-null  object
#  2   Preprocessed  10481 non-null  object
# dtypes: object(3)
# memory usage: 245.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Text          2620 non-null   object
#  1   Task          2620 non-null   object
#  2   Preprocessed  2620 non-null   object
# dtypes: object(3)
# memory usage: 61.5+ KB

# %%
dataset_train['Task'].loc[dataset_train['Task']=="NOT"]=0.0
dataset_train['Task'].loc[dataset_train['Task']=="OFF"]=1.0

dataset_dev['Task'].loc[dataset_train['Task']=="NOT"]=0.0
dataset_dev['Task'].loc[dataset_train['Task']=="OFF"]=1.0

# %%
dataset_train.head()
#dataset_dev.head()
# Out:
#                                                 Text Task  \
# 0  @USER bakkt is doing what an ETF would have do...  1.0
# 1                  @USER I can't 😭😭 he is already 26  0.0
# 2                     @USER he is a psychic ain’t he  0.0
# 3  .@USER @USER and @USER MP @USER praises the 'i...  0.0
# 4  @USER @USER [Eric opens the door and runs to t...  1.0
#
#                                         Preprocessed
# 0        bakkt etf would not call etf FUKEN CUUUUUKS
# 1                                 not 😭 😭 already 26
# 2                                     psychic ai not
# 3  USER MP praise innovative publicsector think w...
# 4                 Eric open door run couch fuck yeah

# %% [markdown]
# #### Beginn Sentiment Analysis CNN

# %%
# Colours
plot_rost = (236 / 255., 116 / 255., 5 / 255.)
plot_blue = (31 / 255., 119 / 255., 180 / 255.)
plot_green = (103 / 255., 191 / 255., 92 / 255.)
plot_grey = (207 / 255., 207 / 255., 207 / 255.)

# %%
# Plot Distribution
reviews_length = [len(tweet.split()) for tweet in dataset_train['Preprocessed']]
plt.figure(figsize=(12,8))
plt.yticks(fontsize=14)    
plt.xticks(fontsize=14)
plt.hist(reviews_length, bins = np.arange(0,50,5), zorder=3, color=plot_rost) 
plt.xlabel('Length', fontsize=13, labelpad=10)
plt.ylabel('Frequency', fontsize=13, labelpad=10)
plt.grid(zorder=0, linewidth=0.5, linestyle='--', color=plot_grey)
plt.tick_params(axis="both", bottom=False, left=False)
plt.box(on=None)
#plt.savefig('./SentencePolarity_review_length.png', dpi=500, transparent=False, bbox_inches='tight')
plt.show()

# %%
# Tokenizer without restriction
tokenizer = Tokenizer()
# Tokenizer fitten 
tokenizer.fit_on_texts(dataset_train['Preprocessed'])

# Length of vocabulary
word_index = tokenizer.word_index
print('Unique Tokens: {}'.format(len(word_index)))
# Out:
# Unique Tokens: 15423

# %%
# maximal numbers of features
max_features = 15000

# Tokenizer mit num_words = max_features
tokenizer = Tokenizer(num_words=max_features)
# Tokenizer fitten 
tokenizer.fit_on_texts(dataset_train['Preprocessed'])

# Tokenizer anwenden
sequences = tokenizer.texts_to_sequences(dataset_train['Preprocessed'])
sequences_test = tokenizer.texts_to_sequences(dataset_test['Preprocessed'])

print(sequences[1])
print(sequences[10])
print(sequences_test[1])
print(sequences_test[10])
# Out:
# [1, 257, 257, 169, 2167]
# [321, 31]
# [389, 111, 4435, 2, 4, 54, 1, 41, 133, 4051, 240, 10, 537, 1082, 1150, 2, 373, 1, 41, 83, 78, 117, 317]
# [419, 1369, 201, 7458, 2826, 36, 100, 43, 225, 7, 315, 419]

# %%
# max_length festlegen
max_length = 40

X = pad_sequences(sequences, maxlen=max_length)
X_testdata = pad_sequences(sequences_test, maxlen=max_length)

# %%
# Convert labels to array
y = np.asarray(dataset_train['Task']).astype("float64")

# Print shapes
print('Shape of data tensor:', X.shape)
print('Shape of label tensor:', y.shape)
# Out:
# Shape of data tensor: (10481, 40)
# Shape of label tensor: (10481,)

# %%
# %%time
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors

word_vectors = KeyedVectors.load_word2vec_format('./Daten/crawl-300d-2M.vec')

embedding_dim = 300
vocabulary_size = min(len(word_index)+1, max_features)
embedding_matrix = np.zeros((vocabulary_size, embedding_dim))

for word, i in word_index.items():
    if i >= max_features:
        continue
    try:
        embedding_vector = word_vectors[word]
        embedding_matrix[i] = embedding_vector
    except KeyError:
        embedding_matrix[i] = word_vectors['unk']
# Out:
# Wall time: 4min 58s

# %%
def cnn_model():
    
    # Input Layer
    input_layer = Input(shape=(max_length, ), dtype='int64')
    
    # Embedding Layer mit Gewichten aus der embedding_matrix
    embedding_layer = Embedding(max_features, embedding_dim, input_length=max_length, 
                                weights=[embedding_matrix])(input_layer)
    
    # Generate Convolutional Layers
    conv_layers = list()
    kernels = [3,4,5]
    for kernel in kernels:
        conv1d = Conv1D(100, kernel_size=kernel, padding='same', activation='relu')(embedding_layer)
        glbmax1d = GlobalMaxPooling1D()(conv1d)
        conv_layers.append(glbmax1d)
    
    # Concatenate
    conc_layer = concatenate(conv_layers, axis=1)
    
    # Fully Connected layer
    drop_1 = Dropout(0.5)(conc_layer)
    dense_1 = Dense(100)(drop_1)
    
    # Output Layer
    output_layer = Dense(1, activation='sigmoid')(dense_1)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    #Adam = F1 0.62
    adam = tf.keras.optimizers.Adam(
    learning_rate=0.0001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-08,
    amsgrad=False,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    jit_compile=True,
    name='Adam'
)

    #AdaDelta = F1 0.03 Shit
    adadelta = tf.keras.optimizers.experimental.Adadelta(
    learning_rate=0.001,
    rho=0.95,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    jit_compile=True,
    name='Adadelta'
)

    #AdaMax = F1 0.62
    adamax = tf.keras.optimizers.experimental.Adamax(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    jit_compile=True,
    name='Adamax',
)

    # Compile Model
    model.compile(optimizer=adamax, loss='binary_focal_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Summary
model = cnn_model()
model.summary()

# Plot Model
plot_model(model, show_layer_names=False)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 40)]         0           []
#
#  embedding_2 (Embedding)        (None, 40, 300)      4500000     ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 40, 100)      90100       ['embedding_2[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 40, 100)      120100      ['embedding_2[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 40, 100)      150100      ['embedding_2[0][0]']
#
#  global_max_pooling1d_6 (Global  (None, 100)         0           ['conv1d_6[0][0]']
#  MaxPooling1D)
#
#  global_max_pooling1d_7 (Global  (None, 100)         0           ['conv1d_7[0][0]']
#  MaxPooling1D)
#
#  global_max_pooling1d_8 (Global  (None, 100)         0           ['conv1d_8[0][0]']
#  MaxPooling1D)
#
#  concatenate_2 (Concatenate)    (None, 300)          0           ['global_max_pooling1d_6[0][0]',
#                                                                   'global_max_pooling1d_7[0][0]',
#                                                                   'global_max_pooling1d_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 300)          0           ['concatenate_2[0][0]']
#
#  dense_4 (Dense)                (None, 100)          30100       ['dropout_2[0][0]']
#
#  dense_5 (Dense)                (None, 1)            101         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,890,501
# Trainable params: 4,890,501
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
seed = 1
# k-Fold Cross-Validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)

history_list = list()
evaluation_list = list()

for fold, [train, test] in enumerate(kfold.split(X, y)):
    
    # Load Model
    model = cnn_model()
    
    print('\n>>> Training | Fold {}'.format(fold+1))
    
    # Test
    X_test = X[test]
    y_test = y[test]
        
    # Callbacks
    path = './models/SentencePolarity_CNN_word_model_fold-{}.hdf5'.format(fold+1)
    checkpoint = ModelCheckpoint(path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=2)
    callbacks_list = [checkpoint]
    
    # Fit Model
    history = model.fit(X[train], y[train], validation_split=0.1,
                        epochs=10, batch_size=100, shuffle=True, callbacks=callbacks_list)
    
    # Append History
    history_list.append(history)

    # Load Best Model
    best_model = load_model(path)
    
    # Evaluate Model
    evaluation = best_model.evaluate(X_test, y_test)
    accuracy = round(evaluation[1], 3)
    loss = round(evaluation[0], 3)
    print('Accuracy: {} | Loss: {}\n'.format(accuracy, loss))
    
    # Precision, Recall, F1-Score
    y_values = best_model.predict(X_test)
    y_pred = [1 if y >= 0.5 else 0 for y in y_values]
    precision = round(precision_score(y_test, y_pred, average='binary'), 3)
    recall = round(recall_score(y_test, y_pred, average='binary'), 3)
    f1 = round(f1_score(y_test, y_pred, average='binary'), 3)
    print('Precision: {} | Recall: {} | F1-Score: {}'.format(precision, recall, f1))
    
    # Append Results
    evaluation_list.append([fold+1, accuracy, loss, precision, recall, f1])
    
    # Delete Model
    del model
    del history
# Out:
# >>> Training | Fold 1
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.6467
# Epoch 1: val_accuracy improved from -inf to 0.75106, saving model to ./models\SentencePolarity_CNN_word_model_fold-1.hdf5
# 85/85 [==============================] - 11s 121ms/step - loss: 0.2088 - accuracy: 0.6467 - val_loss: 0.1338 - val_accuracy: 0.7511
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.7461
# Epoch 2: val_accuracy improved from 0.75106 to 0.75212, saving model to ./models\SentencePolarity_CNN_word_model_fold-1.hdf5
# 85/85 [==============================] - 10s 120ms/step - loss: 0.1383 - accuracy: 0.7461 - val_loss: 0.1330 - val_accuracy: 0.7521
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.7807
# Epoch 3: val_accuracy did not improve from 0.75212
# 85/85 [==============================] - 10s 115ms/step - loss: 0.1214 - accuracy: 0.7807 - val_loss: 0.1295 - val_accuracy: 0.7521
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.8187
# Epoch 4: val_accuracy improved from 0.75212 to 0.77542, saving model to ./models\SentencePolarity_CNN_word_model_fold-1.hdf5
# 85/85 [==============================] - 10s 117ms/step - loss: 0.1061 - accuracy: 0.8187 - val_loss: 0.1283 - val_accuracy: 0.7754
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.8400
# Epoch 5: val_accuracy did not improve from 0.77542
# 85/85 [==============================] - 10s 120ms/step - loss: 0.0960 - accuracy: 0.8400 - val_loss: 0.1306 - val_accuracy: 0.7701
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.8633
# Epoch 6: val_accuracy improved from 0.77542 to 0.78390, saving model to ./models\SentencePolarity_CNN_word_model_fold-1.hdf5
# 85/85 [==============================] - 11s 125ms/step - loss: 0.0853 - accuracy: 0.8633 - val_loss: 0.1289 - val_accuracy: 0.7839
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.8804
# Epoch 7: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 11s 125ms/step - loss: 0.0765 - accuracy: 0.8804 - val_loss: 0.1310 - val_accuracy: 0.7818
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9022
# Epoch 8: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 121ms/step - loss: 0.0662 - accuracy: 0.9022 - val_loss: 0.1350 - val_accuracy: 0.7818
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9201
# Epoch 9: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 11s 127ms/step - loss: 0.0567 - accuracy: 0.9201 - val_loss: 0.1396 - val_accuracy: 0.7797
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9381
# Epoch 10: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 122ms/step - loss: 0.0468 - accuracy: 0.9381 - val_loss: 0.1439 - val_accuracy: 0.7775
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1286 - accuracy: 0.7798
# Accuracy: 0.78 | Loss: 0.129
#
# 33/33 [==============================] - 0s 8ms/step
# Precision: 0.703 | Recall: 0.575 | F1-Score: 0.633
#
# >>> Training | Fold 2
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.6579
# Epoch 1: val_accuracy improved from -inf to 0.76377, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 12s 127ms/step - loss: 0.1922 - accuracy: 0.6579 - val_loss: 0.1301 - val_accuracy: 0.7638
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.7501
# Epoch 2: val_accuracy improved from 0.76377 to 0.77860, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.1331 - accuracy: 0.7501 - val_loss: 0.1249 - val_accuracy: 0.7786
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.7988
# Epoch 3: val_accuracy improved from 0.77860 to 0.78072, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.1154 - accuracy: 0.7988 - val_loss: 0.1233 - val_accuracy: 0.7807
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.8167
# Epoch 4: val_accuracy improved from 0.78072 to 0.78178, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 12s 135ms/step - loss: 0.1044 - accuracy: 0.8167 - val_loss: 0.1236 - val_accuracy: 0.7818
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.8440
# Epoch 5: val_accuracy improved from 0.78178 to 0.79237, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 11s 133ms/step - loss: 0.0933 - accuracy: 0.8440 - val_loss: 0.1235 - val_accuracy: 0.7924
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.8694
# Epoch 6: val_accuracy did not improve from 0.79237
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0822 - accuracy: 0.8694 - val_loss: 0.1253 - val_accuracy: 0.7924
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.8923
# Epoch 7: val_accuracy did not improve from 0.79237
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0711 - accuracy: 0.8923 - val_loss: 0.1304 - val_accuracy: 0.7786
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9153
# Epoch 8: val_accuracy did not improve from 0.79237
# 85/85 [==============================] - 10s 117ms/step - loss: 0.0599 - accuracy: 0.9153 - val_loss: 0.1354 - val_accuracy: 0.7924
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9313
# Epoch 9: val_accuracy improved from 0.79237 to 0.79343, saving model to ./models\SentencePolarity_CNN_word_model_fold-2.hdf5
# 85/85 [==============================] - 10s 120ms/step - loss: 0.0499 - accuracy: 0.9313 - val_loss: 0.1433 - val_accuracy: 0.7934
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9478
# Epoch 10: val_accuracy did not improve from 0.79343
# 85/85 [==============================] - 10s 117ms/step - loss: 0.0417 - accuracy: 0.9478 - val_loss: 0.1488 - val_accuracy: 0.7892
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1396 - accuracy: 0.7729
# Accuracy: 0.773 | Loss: 0.14
#
# 33/33 [==============================] - 0s 7ms/step
# Precision: 0.701 | Recall: 0.543 | F1-Score: 0.612
#
# >>> Training | Fold 3
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.6447
# Epoch 1: val_accuracy improved from -inf to 0.75212, saving model to ./models\SentencePolarity_CNN_word_model_fold-3.hdf5
# 85/85 [==============================] - 11s 118ms/step - loss: 0.2172 - accuracy: 0.6447 - val_loss: 0.1339 - val_accuracy: 0.7521
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.7381
# Epoch 2: val_accuracy did not improve from 0.75212
# 85/85 [==============================] - 10s 116ms/step - loss: 0.1402 - accuracy: 0.7381 - val_loss: 0.1310 - val_accuracy: 0.7511
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.7853
# Epoch 3: val_accuracy improved from 0.75212 to 0.77754, saving model to ./models\SentencePolarity_CNN_word_model_fold-3.hdf5
# 85/85 [==============================] - 10s 119ms/step - loss: 0.1201 - accuracy: 0.7853 - val_loss: 0.1267 - val_accuracy: 0.7775
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.8161
# Epoch 4: val_accuracy did not improve from 0.77754
# 85/85 [==============================] - 10s 115ms/step - loss: 0.1078 - accuracy: 0.8161 - val_loss: 0.1271 - val_accuracy: 0.7775
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.8333
# Epoch 5: val_accuracy did not improve from 0.77754
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0975 - accuracy: 0.8333 - val_loss: 0.1294 - val_accuracy: 0.7754
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.8656
# Epoch 6: val_accuracy improved from 0.77754 to 0.78390, saving model to ./models\SentencePolarity_CNN_word_model_fold-3.hdf5
# 85/85 [==============================] - 10s 120ms/step - loss: 0.0849 - accuracy: 0.8656 - val_loss: 0.1285 - val_accuracy: 0.7839
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.8789
# Epoch 7: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0758 - accuracy: 0.8789 - val_loss: 0.1328 - val_accuracy: 0.7754
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9036
# Epoch 8: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0650 - accuracy: 0.9036 - val_loss: 0.1354 - val_accuracy: 0.7839
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9167
# Epoch 9: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0563 - accuracy: 0.9167 - val_loss: 0.1402 - val_accuracy: 0.7691
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9329
# Epoch 10: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0478 - accuracy: 0.9329 - val_loss: 0.1478 - val_accuracy: 0.7733
# 33/33 [==============================] - 0s 7ms/step - loss: 0.1235 - accuracy: 0.7872
# Accuracy: 0.787 | Loss: 0.124
#
# 33/33 [==============================] - 0s 7ms/step
# Precision: 0.736 | Recall: 0.555 | F1-Score: 0.633
#
# >>> Training | Fold 4
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.6570
# Epoch 1: val_accuracy improved from -inf to 0.75636, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 11s 120ms/step - loss: 0.2124 - accuracy: 0.6570 - val_loss: 0.1304 - val_accuracy: 0.7564
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.7491
# Epoch 2: val_accuracy improved from 0.75636 to 0.76483, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 10s 118ms/step - loss: 0.1364 - accuracy: 0.7491 - val_loss: 0.1298 - val_accuracy: 0.7648
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.7837
# Epoch 3: val_accuracy improved from 0.76483 to 0.78814, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 10s 117ms/step - loss: 0.1190 - accuracy: 0.7837 - val_loss: 0.1217 - val_accuracy: 0.7881
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.8109
# Epoch 4: val_accuracy improved from 0.78814 to 0.79237, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 10s 117ms/step - loss: 0.1076 - accuracy: 0.8109 - val_loss: 0.1212 - val_accuracy: 0.7924
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.8384
# Epoch 5: val_accuracy improved from 0.79237 to 0.79555, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 10s 118ms/step - loss: 0.0963 - accuracy: 0.8384 - val_loss: 0.1221 - val_accuracy: 0.7956
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.8593
# Epoch 6: val_accuracy improved from 0.79555 to 0.79661, saving model to ./models\SentencePolarity_CNN_word_model_fold-4.hdf5
# 85/85 [==============================] - 10s 118ms/step - loss: 0.0851 - accuracy: 0.8593 - val_loss: 0.1227 - val_accuracy: 0.7966
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.8794
# Epoch 7: val_accuracy did not improve from 0.79661
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0749 - accuracy: 0.8794 - val_loss: 0.1266 - val_accuracy: 0.7956
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9058
# Epoch 8: val_accuracy did not improve from 0.79661
# 85/85 [==============================] - 10s 117ms/step - loss: 0.0645 - accuracy: 0.9058 - val_loss: 0.1382 - val_accuracy: 0.7828
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9224
# Epoch 9: val_accuracy did not improve from 0.79661
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0546 - accuracy: 0.9224 - val_loss: 0.1342 - val_accuracy: 0.7871
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9406
# Epoch 10: val_accuracy did not improve from 0.79661
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0456 - accuracy: 0.9406 - val_loss: 0.1433 - val_accuracy: 0.7818
# 33/33 [==============================] - 0s 7ms/step - loss: 0.1380 - accuracy: 0.7681
# Accuracy: 0.768 | Loss: 0.138
#
# 33/33 [==============================] - 0s 7ms/step
# Precision: 0.689 | Recall: 0.539 | F1-Score: 0.605
#
# >>> Training | Fold 5
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1948 - accuracy: 0.6566
# Epoch 1: val_accuracy improved from -inf to 0.74364, saving model to ./models\SentencePolarity_CNN_word_model_fold-5.hdf5
# 85/85 [==============================] - 11s 117ms/step - loss: 0.1948 - accuracy: 0.6566 - val_loss: 0.1334 - val_accuracy: 0.7436
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.7532
# Epoch 2: val_accuracy improved from 0.74364 to 0.75530, saving model to ./models\SentencePolarity_CNN_word_model_fold-5.hdf5
# 85/85 [==============================] - 10s 117ms/step - loss: 0.1331 - accuracy: 0.7532 - val_loss: 0.1273 - val_accuracy: 0.7553
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.7944
# Epoch 3: val_accuracy improved from 0.75530 to 0.76165, saving model to ./models\SentencePolarity_CNN_word_model_fold-5.hdf5
# 85/85 [==============================] - 10s 118ms/step - loss: 0.1170 - accuracy: 0.7944 - val_loss: 0.1273 - val_accuracy: 0.7617
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.8227
# Epoch 4: val_accuracy improved from 0.76165 to 0.77331, saving model to ./models\SentencePolarity_CNN_word_model_fold-5.hdf5
# 85/85 [==============================] - 10s 122ms/step - loss: 0.1050 - accuracy: 0.8227 - val_loss: 0.1258 - val_accuracy: 0.7733
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.8400
# Epoch 5: val_accuracy improved from 0.77331 to 0.77860, saving model to ./models\SentencePolarity_CNN_word_model_fold-5.hdf5
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0942 - accuracy: 0.8400 - val_loss: 0.1271 - val_accuracy: 0.7786
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.8735
# Epoch 6: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 10s 118ms/step - loss: 0.0799 - accuracy: 0.8735 - val_loss: 0.1294 - val_accuracy: 0.7744
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.8981
# Epoch 7: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0682 - accuracy: 0.8981 - val_loss: 0.1343 - val_accuracy: 0.7786
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9155
# Epoch 8: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 10s 117ms/step - loss: 0.0568 - accuracy: 0.9155 - val_loss: 0.1409 - val_accuracy: 0.7733
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9330
# Epoch 9: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 10s 114ms/step - loss: 0.0480 - accuracy: 0.9330 - val_loss: 0.1464 - val_accuracy: 0.7733
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9466
# Epoch 10: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 10s 114ms/step - loss: 0.0397 - accuracy: 0.9466 - val_loss: 0.1589 - val_accuracy: 0.7754
# 33/33 [==============================] - 0s 7ms/step - loss: 0.1211 - accuracy: 0.7939
# Accuracy: 0.794 | Loss: 0.121
#
# 33/33 [==============================] - 0s 7ms/step
# Precision: 0.742 | Recall: 0.574 | F1-Score: 0.647
#
# >>> Training | Fold 6
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1875 - accuracy: 0.6667
# Epoch 1: val_accuracy improved from -inf to 0.75847, saving model to ./models\SentencePolarity_CNN_word_model_fold-6.hdf5
# 85/85 [==============================] - 11s 117ms/step - loss: 0.1875 - accuracy: 0.6667 - val_loss: 0.1281 - val_accuracy: 0.7585
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.7612
# Epoch 2: val_accuracy improved from 0.75847 to 0.78284, saving model to ./models\SentencePolarity_CNN_word_model_fold-6.hdf5
# 85/85 [==============================] - 10s 119ms/step - loss: 0.1294 - accuracy: 0.7612 - val_loss: 0.1239 - val_accuracy: 0.7828
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.7911
# Epoch 3: val_accuracy improved from 0.78284 to 0.79025, saving model to ./models\SentencePolarity_CNN_word_model_fold-6.hdf5
# 85/85 [==============================] - 10s 117ms/step - loss: 0.1169 - accuracy: 0.7911 - val_loss: 0.1215 - val_accuracy: 0.7903
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.8206
# Epoch 4: val_accuracy improved from 0.79025 to 0.79449, saving model to ./models\SentencePolarity_CNN_word_model_fold-6.hdf5
# 85/85 [==============================] - 10s 118ms/step - loss: 0.1032 - accuracy: 0.8206 - val_loss: 0.1220 - val_accuracy: 0.7945
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.8499
# Epoch 5: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 114ms/step - loss: 0.0918 - accuracy: 0.8499 - val_loss: 0.1249 - val_accuracy: 0.7903
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.8723
# Epoch 6: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 114ms/step - loss: 0.0797 - accuracy: 0.8723 - val_loss: 0.1310 - val_accuracy: 0.7786
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.8966
# Epoch 7: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0672 - accuracy: 0.8966 - val_loss: 0.1322 - val_accuracy: 0.7892
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9207
# Epoch 8: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0559 - accuracy: 0.9207 - val_loss: 0.1407 - val_accuracy: 0.7839
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9378
# Epoch 9: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0463 - accuracy: 0.9378 - val_loss: 0.1470 - val_accuracy: 0.7839
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9485
# Epoch 10: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0380 - accuracy: 0.9485 - val_loss: 0.1535 - val_accuracy: 0.7828
# 33/33 [==============================] - 0s 7ms/step - loss: 0.1273 - accuracy: 0.7576
# Accuracy: 0.758 | Loss: 0.127
#
# 33/33 [==============================] - 0s 7ms/step
# Precision: 0.656 | Recall: 0.554 | F1-Score: 0.601
#
# >>> Training | Fold 7
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.6523
# Epoch 1: val_accuracy improved from -inf to 0.74894, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 11s 121ms/step - loss: 0.2065 - accuracy: 0.6523 - val_loss: 0.1321 - val_accuracy: 0.7489
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.7450
# Epoch 2: val_accuracy improved from 0.74894 to 0.75953, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 10s 120ms/step - loss: 0.1374 - accuracy: 0.7450 - val_loss: 0.1278 - val_accuracy: 0.7595
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.7801
# Epoch 3: val_accuracy improved from 0.75953 to 0.76589, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 10s 121ms/step - loss: 0.1213 - accuracy: 0.7801 - val_loss: 0.1258 - val_accuracy: 0.7659
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.8165
# Epoch 4: val_accuracy improved from 0.76589 to 0.77013, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.1070 - accuracy: 0.8165 - val_loss: 0.1249 - val_accuracy: 0.7701
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.8425
# Epoch 5: val_accuracy improved from 0.77013 to 0.77860, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 11s 134ms/step - loss: 0.0960 - accuracy: 0.8425 - val_loss: 0.1255 - val_accuracy: 0.7786
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.8632
# Epoch 6: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 11s 125ms/step - loss: 0.0866 - accuracy: 0.8632 - val_loss: 0.1296 - val_accuracy: 0.7775
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.8776
# Epoch 7: val_accuracy did not improve from 0.77860
# 85/85 [==============================] - 11s 124ms/step - loss: 0.0783 - accuracy: 0.8776 - val_loss: 0.1285 - val_accuracy: 0.7733
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9010
# Epoch 8: val_accuracy improved from 0.77860 to 0.78708, saving model to ./models\SentencePolarity_CNN_word_model_fold-7.hdf5
# 85/85 [==============================] - 11s 126ms/step - loss: 0.0665 - accuracy: 0.9010 - val_loss: 0.1287 - val_accuracy: 0.7871
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9179
# Epoch 9: val_accuracy did not improve from 0.78708
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0569 - accuracy: 0.9179 - val_loss: 0.1332 - val_accuracy: 0.7786
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9338
# Epoch 10: val_accuracy did not improve from 0.78708
# 85/85 [==============================] - 11s 125ms/step - loss: 0.0492 - accuracy: 0.9338 - val_loss: 0.1433 - val_accuracy: 0.7818
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1297 - accuracy: 0.7748
# Accuracy: 0.775 | Loss: 0.13
#
# 33/33 [==============================] - 0s 8ms/step
# Precision: 0.687 | Recall: 0.58 | F1-Score: 0.629
#
# >>> Training | Fold 8
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.6609
# Epoch 1: val_accuracy improved from -inf to 0.74470, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 12s 128ms/step - loss: 0.1797 - accuracy: 0.6609 - val_loss: 0.1328 - val_accuracy: 0.7447
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.7599
# Epoch 2: val_accuracy improved from 0.74470 to 0.76589, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.1299 - accuracy: 0.7599 - val_loss: 0.1271 - val_accuracy: 0.7659
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.7913
# Epoch 3: val_accuracy improved from 0.76589 to 0.78178, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 11s 127ms/step - loss: 0.1167 - accuracy: 0.7913 - val_loss: 0.1264 - val_accuracy: 0.7818
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.8237
# Epoch 4: val_accuracy did not improve from 0.78178
# 85/85 [==============================] - 11s 125ms/step - loss: 0.1032 - accuracy: 0.8237 - val_loss: 0.1273 - val_accuracy: 0.7765
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.8539
# Epoch 5: val_accuracy improved from 0.78178 to 0.78284, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 11s 127ms/step - loss: 0.0893 - accuracy: 0.8539 - val_loss: 0.1303 - val_accuracy: 0.7828
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.8758
# Epoch 6: val_accuracy improved from 0.78284 to 0.78390, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 11s 129ms/step - loss: 0.0771 - accuracy: 0.8758 - val_loss: 0.1352 - val_accuracy: 0.7839
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.8989
# Epoch 7: val_accuracy did not improve from 0.78390
# 85/85 [==============================] - 11s 127ms/step - loss: 0.0661 - accuracy: 0.8989 - val_loss: 0.1426 - val_accuracy: 0.7828
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9219
# Epoch 8: val_accuracy improved from 0.78390 to 0.78602, saving model to ./models\SentencePolarity_CNN_word_model_fold-8.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.0541 - accuracy: 0.9219 - val_loss: 0.1497 - val_accuracy: 0.7860
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9420
# Epoch 9: val_accuracy did not improve from 0.78602
# 85/85 [==============================] - 11s 124ms/step - loss: 0.0445 - accuracy: 0.9420 - val_loss: 0.1650 - val_accuracy: 0.7775
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9557
# Epoch 10: val_accuracy did not improve from 0.78602
# 85/85 [==============================] - 11s 124ms/step - loss: 0.0351 - accuracy: 0.9557 - val_loss: 0.1710 - val_accuracy: 0.7850
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1459 - accuracy: 0.7767
# Accuracy: 0.777 | Loss: 0.146
#
# 33/33 [==============================] - 0s 9ms/step
# Precision: 0.732 | Recall: 0.507 | F1-Score: 0.599
#
# >>> Training | Fold 9
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.6484
# Epoch 1: val_accuracy improved from -inf to 0.76907, saving model to ./models\SentencePolarity_CNN_word_model_fold-9.hdf5
# 85/85 [==============================] - 12s 128ms/step - loss: 0.2064 - accuracy: 0.6484 - val_loss: 0.1323 - val_accuracy: 0.7691
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.7466
# Epoch 2: val_accuracy improved from 0.76907 to 0.78284, saving model to ./models\SentencePolarity_CNN_word_model_fold-9.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.1381 - accuracy: 0.7466 - val_loss: 0.1272 - val_accuracy: 0.7828
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.7894
# Epoch 3: val_accuracy did not improve from 0.78284
# 85/85 [==============================] - 11s 124ms/step - loss: 0.1188 - accuracy: 0.7894 - val_loss: 0.1269 - val_accuracy: 0.7744
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.8180
# Epoch 4: val_accuracy improved from 0.78284 to 0.78814, saving model to ./models\SentencePolarity_CNN_word_model_fold-9.hdf5
# 85/85 [==============================] - 11s 126ms/step - loss: 0.1060 - accuracy: 0.8180 - val_loss: 0.1246 - val_accuracy: 0.7881
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.8400
# Epoch 5: val_accuracy did not improve from 0.78814
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0965 - accuracy: 0.8400 - val_loss: 0.1257 - val_accuracy: 0.7850
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.8575
# Epoch 6: val_accuracy did not improve from 0.78814
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0865 - accuracy: 0.8575 - val_loss: 0.1279 - val_accuracy: 0.7881
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.8803
# Epoch 7: val_accuracy did not improve from 0.78814
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0745 - accuracy: 0.8803 - val_loss: 0.1306 - val_accuracy: 0.7881
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9081
# Epoch 8: val_accuracy did not improve from 0.78814
# 85/85 [==============================] - 11s 125ms/step - loss: 0.0629 - accuracy: 0.9081 - val_loss: 0.1362 - val_accuracy: 0.7850
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9247
# Epoch 9: val_accuracy improved from 0.78814 to 0.79449, saving model to ./models\SentencePolarity_CNN_word_model_fold-9.hdf5
# 85/85 [==============================] - 11s 132ms/step - loss: 0.0544 - accuracy: 0.9247 - val_loss: 0.1399 - val_accuracy: 0.7945
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9392
# Epoch 10: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 123ms/step - loss: 0.0453 - accuracy: 0.9392 - val_loss: 0.1477 - val_accuracy: 0.7903
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1387 - accuracy: 0.7653
# Accuracy: 0.765 | Loss: 0.139
#
# 33/33 [==============================] - 0s 8ms/step
# Precision: 0.683 | Recall: 0.536 | F1-Score: 0.601
#
# >>> Training | Fold 10
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.6662
# Epoch 1: val_accuracy improved from -inf to 0.75847, saving model to ./models\SentencePolarity_CNN_word_model_fold-10.hdf5
# 85/85 [==============================] - 12s 127ms/step - loss: 0.1933 - accuracy: 0.6662 - val_loss: 0.1329 - val_accuracy: 0.7585
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.7595
# Epoch 2: val_accuracy improved from 0.75847 to 0.77331, saving model to ./models\SentencePolarity_CNN_word_model_fold-10.hdf5
# 85/85 [==============================] - 11s 126ms/step - loss: 0.1324 - accuracy: 0.7595 - val_loss: 0.1294 - val_accuracy: 0.7733
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.7983
# Epoch 3: val_accuracy did not improve from 0.77331
# 85/85 [==============================] - 10s 123ms/step - loss: 0.1140 - accuracy: 0.7983 - val_loss: 0.1318 - val_accuracy: 0.7701
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.8261
# Epoch 4: val_accuracy improved from 0.77331 to 0.77648, saving model to ./models\SentencePolarity_CNN_word_model_fold-10.hdf5
# 85/85 [==============================] - 11s 127ms/step - loss: 0.1018 - accuracy: 0.8261 - val_loss: 0.1304 - val_accuracy: 0.7765
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.8498
# Epoch 5: val_accuracy improved from 0.77648 to 0.78708, saving model to ./models\SentencePolarity_CNN_word_model_fold-10.hdf5
# 85/85 [==============================] - 11s 133ms/step - loss: 0.0915 - accuracy: 0.8498 - val_loss: 0.1301 - val_accuracy: 0.7871
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.8758
# Epoch 6: val_accuracy improved from 0.78708 to 0.79449, saving model to ./models\SentencePolarity_CNN_word_model_fold-10.hdf5
# 85/85 [==============================] - 11s 128ms/step - loss: 0.0782 - accuracy: 0.8758 - val_loss: 0.1306 - val_accuracy: 0.7945
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9012
# Epoch 7: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 117ms/step - loss: 0.0668 - accuracy: 0.9012 - val_loss: 0.1417 - val_accuracy: 0.7934
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9137
# Epoch 8: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0577 - accuracy: 0.9137 - val_loss: 0.1408 - val_accuracy: 0.7945
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9342
# Epoch 9: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 118ms/step - loss: 0.0475 - accuracy: 0.9342 - val_loss: 0.1470 - val_accuracy: 0.7818
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9471
# Epoch 10: val_accuracy did not improve from 0.79449
# 85/85 [==============================] - 10s 116ms/step - loss: 0.0406 - accuracy: 0.9471 - val_loss: 0.1527 - val_accuracy: 0.7839
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1389 - accuracy: 0.7643
# Accuracy: 0.764 | Loss: 0.139
#
# 33/33 [==============================] - 0s 8ms/step
# Precision: 0.687 | Recall: 0.522 | F1-Score: 0.593

# %%
# Export Results
acc_avg = [i[1] for i in evaluation_list]
loss_avg = [i[2] for i in evaluation_list]
prec_avg = [i[3] for i in evaluation_list]
recall_avg = [i[4] for i in evaluation_list]
f1_avg = [i[5] for i in evaluation_list]

evaluation_list.append(['AVG',
                        round(np.mean(acc_avg), 4),
                        round(np.mean(loss_avg), 4), 
                        round(np.mean(prec_avg), 4),
                        round(np.mean(recall_avg), 4),
                        round(np.mean(f1_avg), 4)])


evaluation_df = pd.DataFrame(evaluation_list, columns=['Fold', 'Accuracy', 'Loss', 'Precision', 'Recall', 'F1-Score'])
#evaluation_df.to_csv('./Wine_SVM_evaluation.csv', index=False, sep=';')
print(evaluation_df)
# Out:
#    Fold  Accuracy    Loss  Precision  Recall  F1-Score
# 0     1    0.7800  0.1290     0.7030  0.5750    0.6330
# 1     2    0.7730  0.1400     0.7010  0.5430    0.6120
# 2     3    0.7870  0.1240     0.7360  0.5550    0.6330
# 3     4    0.7680  0.1380     0.6890  0.5390    0.6050
# 4     5    0.7940  0.1210     0.7420  0.5740    0.6470
# 5     6    0.7580  0.1270     0.6560  0.5540    0.6010
# 6     7    0.7750  0.1300     0.6870  0.5800    0.6290
# 7     8    0.7770  0.1460     0.7320  0.5070    0.5990
# 8     9    0.7650  0.1390     0.6830  0.5360    0.6010
# 9    10    0.7640  0.1390     0.6870  0.5220    0.5930
# 10  AVG    0.7741  0.1333     0.7016  0.5485    0.6153

# %%
path =  './models/SentencePolarity_CNN_word_model_fold-{}.hdf5'.format(4)
best_model = load_model(path)
prediction = best_model.predict(X_testdata)

dataset_testnr = dataset_test
dataset_testnr['prediction'] = prediction
dataset_testnr.to_csv('./pred/predictionnr.csv')

dataset_testr = dataset_test
prediction = np.array(list(map(np.round, prediction)))
prediction = prediction.astype("int")
dataset_testr['prediction'] = prediction
dataset_testr.to_csv('./pred/predictionr.csv')
# Out:
# 30/30 [==============================] - 0s 8ms/step
